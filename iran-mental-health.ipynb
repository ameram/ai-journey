# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/kaggle/input/iran-mental-health-with-pop/iran-mental-health_data.csv')

# %%
df.head(4)
